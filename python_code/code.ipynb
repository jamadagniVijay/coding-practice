# %%
# https://techiedelight.com/find-pair-with-given-sum-array/
# Find a pair with the given sum in an array
# Given an unsorted integer array, find a pair with the given sum in it.
nums = [8, 7, 2, 5, 3, 1]
target = 10

# Approach 1: 
# define pairs = []
# loop through the array, start from 0th index
    # if target - element == loop through the array from 1 to nth element
        # time complexity - O(n^2)
# Approach 2:
    # define pairs = []
    # nums_set = set(nums)
    # loop through the set get the position of value of (target - element)
    # if found - add (arr(position),arr(position of value of (target - element)))
    # appends duplicate
pairs = set()

nums_set = set(nums)
for num in nums.copy():
    comp = target - num
    if (comp in nums_set) and (comp > 0) and (num!=comp) :
        if num > comp :
            num,comp = comp,num
        pairs.add((num,comp))

print(pairs)
# Out:
# {(3, 7), (2, 8)}

# %%
# https://www.techiedelight.com/check-subarray-with-0-sum-exists-not/
# Check if a subarray with 0 sum exists or not
    # Input:  { 3, 4, -7, 3, 1, 3, 1, -4, -2, -2 } Output: Subarray with zero-sum exists
    # The subarrays with a sum of 0 are: 
    # { 3, 4, -7 }
    # { 4, -7, 3 }
    # { -7, 3, 1, 3 }
    # { 3, 1, -4 }
    # { 3, 1, 3, 1, -4, -2, -2 }
    # { 3, 4, -7, 3, 1, 3, 1, -4, -2, -2 } 
    
    # run through the array and create arrays of array that contains numbers that add upto 0 

nums = ""
nums = [3, 4, -7, 3, 1, 3, 1, -4, -2, -2 ]
sum_after_each = {0: [-1]}
running_total = 0
current_index = 
for num in nums:
    running_total = running_total + num
    if sum_after_each[sum] > 0:
# Out:
# [[3, 4, -7], [4, -7, 3, 1, 3, 1, -4, -2, -2]]
